# %%
import os
os.getcwd()
# Out:
# '/home/edd/Documents/projects/slack-nlp/notebooks'

# %%
import sys
import importlib
import re

import itertools as it
import pandas as pd

from gensim.parsing.preprocessing import strip_numeric, strip_punctuation, strip_tags, strip_multiple_whitespaces, strip_short, remove_stopwords

src_dir = "../src/"
sys.path.append(src_dir)
import data.processing
from data.processing import format_ts, tokenise_text_col, to_lower, remove_links, remove_blanks, text_proc_pipeline

# %%
importlib.reload(data.processing)
# Out:
# <module 'data.processing' from '../src/data/processing.py'>

# %%
df = pd.read_csv("../data/interim/slack_data.csv", index_col = 0)
# Out:
# /home/edd/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (3,6,13,15,17,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Format timestamps

# %%
format_ts(df,
          save_to_csv = True,
          verbose = True)
# Out:
# 2018-12-23 21:41:22,084 - data.processing - INFO - converting columns to timedate format
# 2018-12-23 21:41:22,085 - data.processing - INFO - ...latest_reply
# 2018-12-23 21:41:22,094 - data.processing - INFO - ...thread_ts
# 2018-12-23 21:41:22,112 - data.processing - INFO - ...ts
# 2018-12-23 21:41:22,610 - data.processing - INFO - saving to ../data/interim/slack_data_ts.csv
#                                           attachments     bot_id bot_link  \
# 0   [{'title': 'Explosive Research Scientist - Civ...        NaN      NaN
# 1                                                 NaN        NaN      NaN
# 0                                                 NaN        NaN      NaN
# 1                                                 NaN        NaN      NaN
# 0   [{'service_name': 'Potato', 'title': 'Jobs', '...        NaN      NaN
# 1                                                 NaN        NaN      NaN
# 2                                                 NaN        NaN      NaN
# ...

# %% [markdown]
# # cleaning text

# %%
df = text_proc_pipeline(df, verbose=True)
# Out:
# 2018-12-23 21:42:39,151 - data.processing - INFO - starting processing pipeline
# 2018-12-23 21:42:39,152 - data.processing - INFO - storing unprocessed text in text_unproc
# 2018-12-23 21:42:39,155 - data.processing - INFO - removing html
# 2018-12-23 21:42:39,260 - data.processing - INFO - removing multiple spaces
# 2018-12-23 21:42:39,852 - data.processing - INFO - removing punctuation
# 2018-12-23 21:42:40,253 - data.processing - INFO - removing numeric
# 2018-12-23 21:42:40,503 - data.processing - INFO - removing characters less than 2
# 2018-12-23 21:42:40,829 - data.processing - INFO - converting text to lower case
# 2018-12-23 21:42:40,888 - data.processing - INFO - removing stopwords; stored in text_no_stopwords
# 2018-12-23 21:42:41,171 - data.processing - INFO - complete
#                                           attachments     bot_id bot_link  \
# 0   [{'title': 'Explosive Research Scientist - Civ...        NaN      NaN
# ...

# %% [markdown]
# lets tokenise the words

# %%
df = tokenise_text_col(df, text_col = "text")

# %%
df = tokenise_text_col(df, text_col = "text_no_stopwords")

# %%
df.head()
# Out:
#                                          attachments bot_id bot_link channel  \
# 0  [{'title': 'Explosive Research Scientist - Civ...    NaN      NaN    jobs
# 1                                                NaN    NaN      NaN    jobs
# 0                                                NaN    NaN      NaN    jobs
# 1                                                NaN    NaN      NaN    jobs
# 0  [{'service_name': 'Potato', 'title': 'Jobs', '...    NaN      NaN    jobs
#
#                           client_msg_id display_as_bot edited files icons  \
# 0  19528caa-200a-4c5c-a6f8-3a828d5aca85            NaN    NaN   NaN   NaN
# 1  aa156292-1d78-48da-bc2c-1b77af8b72e5            NaN    NaN   NaN   NaN
# 0                                   NaN            NaN    NaN   NaN   NaN
# 1                                   NaN            NaN    NaN   NaN   NaN
# 0  d834ffa6-c6d3-4334-936b-916cba6e7ff2            NaN    NaN   NaN   NaN
#
# ...

# %%
df.to_csv("../data/processed/clean_tokenised_text.csv")
