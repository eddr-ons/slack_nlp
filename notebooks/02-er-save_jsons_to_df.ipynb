# %%
import sys
import os
import importlib

# %%
importlib.reload(data.loading)
# Out:
# <module 'data.loading' from '../src/data/loading.py'>

# %%
src_dir = "../src/"
sys.path.append(src_dir)

# %%
from data.loading import json_to_df

# %%
df = json_to_df(verbose = True, save_to_csv = True)
# Out:
# 2018-12-16 15:41:59,432 - data.loading - INFO - Creating DataFrame from jsons
# 2018-12-16 15:41:59,434 - data.loading - INFO - loading jsons from...
# 2018-12-16 15:41:59,435 - data.loading - INFO - 	jobs
# 2018-12-16 15:41:59,615 - data.loading - INFO - 	giphy
# 2018-12-16 15:41:59,623 - data.loading - INFO - 	doom
# 2018-12-16 15:42:01,706 - data.loading - INFO - 	vinyl
# 2018-12-16 15:42:01,991 - data.loading - INFO - 	rocket_comps
# 2018-12-16 15:42:01,996 - data.loading - INFO - 	notpython
# 2018-12-16 15:42:02,111 - data.loading - INFO - 	music_feeds
# 2018-12-16 15:42:06,350 - data.loading - INFO - 	amfest
# 2018-12-16 15:42:06,399 - data.loading - INFO - 	jazz-experimental
# 2018-12-16 15:42:06,473 - data.loading - INFO - 	gamedev
# 2018-12-16 15:42:06,525 - data.loading - INFO - 	notdoom
# 2018-12-16 15:42:07,412 - data.loading - INFO - 	日本語
# 2018-12-16 15:42:07,451 - data.loading - INFO - 	techno
# 2018-12-16 15:42:07,481 - data.loading - INFO - 	random
# ...

# %%
df.head()
# Out:
#                                          attachments bot_id bot_link channel  \
# 0  [{'title': 'Explosive Research Scientist - Civ...    NaN      NaN    jobs
# 1                                                NaN    NaN      NaN    jobs
# 0                                                NaN    NaN      NaN    jobs
# 1                                                NaN    NaN      NaN    jobs
# 0  [{'service_name': 'Potato', 'title': 'Jobs', '...    NaN      NaN    jobs
#
#                           client_msg_id display_as_bot edited files icons  \
# 0  19528caa-200a-4c5c-a6f8-3a828d5aca85            NaN    NaN   NaN   NaN
# 1  aa156292-1d78-48da-bc2c-1b77af8b72e5            NaN    NaN   NaN   NaN
# 0                                   NaN            NaN    NaN   NaN   NaN
# 1                                   NaN            NaN    NaN   NaN   NaN
# 0  d834ffa6-c6d3-4334-936b-916cba6e7ff2            NaN    NaN   NaN   NaN
#
#   inviter    ...    root            subtype  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105812 entries, 0 to 14
# Data columns (total 32 columns):
# attachments          24524 non-null object
# bot_id               19922 non-null object
# bot_link             13 non-null object
# channel              105812 non-null object
# client_msg_id        9852 non-null object
# display_as_bot       360 non-null object
# edited               2178 non-null object
# files                360 non-null object
# icons                7647 non-null object
# inviter              359 non-null object
# item_type            39 non-null object
# latest_reply         261 non-null float64
# name                 6 non-null object
# new_broadcast        2 non-null float64
# old_name             6 non-null object
# parent_user_id       1418 non-null object
# purpose              48 non-null object
# reactions            1284 non-null object
# replies              261 non-null object
# reply_count          261 non-null float64
# ...

# %%
df.describe()
# Out:
#        latest_reply  new_broadcast  reply_count  reply_users_count  \
# count  2.610000e+02            2.0   261.000000         261.000000
# mean   1.502173e+09            1.0     5.750958           1.743295
# std    1.631776e+08            0.0    17.838033           0.798558
# min    0.000000e+00            1.0     0.000000           0.000000
# 25%    1.507077e+09            1.0     1.000000           1.000000
# 50%    1.521586e+09            1.0     2.000000           2.000000
# 75%    1.534702e+09            1.0     5.000000           2.000000
# max    1.543242e+09            1.0   267.000000           5.000000
#
#           thread_ts            ts
# count  1.762000e+03  1.058120e+05
# mean   1.525521e+09  1.485959e+09
# std    1.712433e+07  2.922128e+07
# min    1.484871e+09  1.441203e+09
# 25%    1.512988e+09  1.460581e+09
# 50%    1.532470e+09  1.481140e+09
# 75%    1.541677e+09  1.511278e+09
# max    1.543237e+09  1.543528e+09
